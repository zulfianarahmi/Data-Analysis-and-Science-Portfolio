# %% [markdown]
# #  Exploratory Data Analysis (EDA) for Heart Disease Prediction

# %% [markdown]
# ## Introduction
#
# In this notebook, we conduct Exploratory Data Analysis (EDA) on a dataset related to heart disease detection. The primary objectives are:
#
# 1. Age Distribution Analysis:
# 2. Gender Analysis:
# 3. Relationship between Resting Blood Pressure and Serum Cholesterol
# 4. Chest Pain Type Analysis:
# 5. Resting Electrocardiogram Analysis:
# 6. Maximum Heart Rate Analysis:

# %%
#Import Required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load Data
data = pd.read_csv("D:\VIDEO\Belajar\DATA ANALYST\dataset\Cardiovascular_Disease_Dataset.csv")
data
# Out:
#      patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0       103368   53       1          2        171                0
# 1       119250   40       1          0         94              229
# 2       119372   49       1          2        133              142
# 3       132514   43       1          0        138              295
# 4       146211   31       1          1        199                0
# ..         ...  ...     ...        ...        ...              ...
# 995    9949544   48       1          2        139              349
# 996    9953423   47       1          3        143              258
# 997    9965859   69       1          0        156              434
# 998    9988507   45       1          1        186              417
# 999    9990855   25       1          0        158              270
#
#      fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                    0                1           147              0      5.3
# ...

# %%
# Rename Head Columns
data.rename(columns={'patientid':'PatientId','age':'Age','gender':'Gender','chestpain':'ChestPain',
                     'restingBP':'RestingBP','serumcholestrol':'SerumCholestrol','fastingbloodsugar':'FastingBloodSugar',
                     'restingrelectro':'RestingrElectro','maxheartrate':'MaxHeartRate','exerciseangia':'ExercIseangia',
                     'oldpeak':'OldPeak','slope':'Slope','noofmajorvessels':'NoOfMajorVessels','target':'Target'}, inplace=True)

# %%
# Showing the Dataset
data
# Out:
#      PatientId  Age  Gender  ChestPain  RestingBP  SerumCholestrol  \
# 0       103368   53       1          2        171                0
# 1       119250   40       1          0         94              229
# 2       119372   49       1          2        133              142
# 3       132514   43       1          0        138              295
# 4       146211   31       1          1        199                0
# ..         ...  ...     ...        ...        ...              ...
# 995    9949544   48       1          2        139              349
# 996    9953423   47       1          3        143              258
# 997    9965859   69       1          0        156              434
# 998    9988507   45       1          1        186              417
# 999    9990855   25       1          0        158              270
#
#      FastingBloodSugar  RestingrElectro  MaxHeartRate  ExercIseangia  OldPeak  \
# 0                    0                1           147              0      5.3
# ...

# %%
# Knowing the Number of Rows and Columns
data.shape
# Out:
# (1000, 14)

# %%
# Displaying the Renamed Columns
data.columns
# Out:
# Index(['PatientId', 'Age', 'Gender', 'ChestPain', 'RestingBP',
#        'SerumCholestrol', 'FastingBloodSugar', 'RestingrElectro',
#        'MaxHeartRate', 'ExercIseangia', 'OldPeak', 'Slope', 'NoOfMajorVessels',
#        'Target'],
#       dtype='object')

# %%
# Displaying the Data Types of Each Column
data.dtypes
# Out:
# PatientId              int64
# Age                    int64
# Gender                 int64
# ChestPain              int64
# RestingBP              int64
# SerumCholestrol        int64
# FastingBloodSugar      int64
# RestingrElectro        int64
# MaxHeartRate           int64
# ExercIseangia          int64
# OldPeak              float64
# Slope                  int64
# NoOfMajorVessels       int64
# Target                 int64
# dtype: object

# %%
# Displaying Information About the Dataset
data.info
# Out:
# <bound method DataFrame.info of      PatientId  Age  Gender  ChestPain  RestingBP  SerumCholestrol  \
# 0       103368   53       1          2        171                0
# 1       119250   40       1          0         94              229
# 2       119372   49       1          2        133              142
# 3       132514   43       1          0        138              295
# 4       146211   31       1          1        199                0
# ..         ...  ...     ...        ...        ...              ...
# 995    9949544   48       1          2        139              349
# 996    9953423   47       1          3        143              258
# 997    9965859   69       1          0        156              434
# 998    9988507   45       1          1        186              417
# 999    9990855   25       1          0        158              270
#
#      FastingBloodSugar  RestingrElectro  MaxHeartRate  ExercIseangia  OldPeak  \
# ...

# %% [markdown]
# ### Identify missing value

# %%
data.isna().values.any()
# Out:
# False

# %%
data.isna().sum()
# Out:
# PatientId            0
# Age                  0
# Gender               0
# ChestPain            0
# RestingBP            0
# SerumCholestrol      0
# FastingBloodSugar    0
# RestingrElectro      0
# MaxHeartRate         0
# ExercIseangia        0
# OldPeak              0
# Slope                0
# NoOfMajorVessels     0
# Target               0
# dtype: int64

# %% [markdown]
# ### Identify duplicate entries/rows

# %%
data.duplicated().values.any()
# Out:
# False

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Age Distribution Analysis:
#
# Understanding the age distribution helps identify age ranges more vulnerable to heart disease, guiding more effective prevention and early detection campaigns.

# %%
#Visualizing the Age Distribution (Analyst)
fig = plt.figure(figsize=(10, 6))
plt.hist(data['Age'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Number of Individuals')
plt.show()

# %% [markdown]
# ## Gender Analysis:
# Understanding the gender distribution in the dataset can aid in developing targeted solutions based on population characteristics.

# %%
# Analyzing Gender Distribution
gender_counts = data['Gender'].value_counts()
gender_counts
# Out:
# 1    765
# 0    235
# Name: Gender, dtype: int64

# %%
# Creating a pie chart for gender distribution
plt.figure(figsize=(8, 8))
plt.pie(gender_counts, labels=['Female (0)', 'Male (1)'], autopct='%1.1f%%', colors=['lightcoral', 'peachpuff'], startangle=90)
plt.title('Distribution of Gender')
plt.show()

# %% [markdown]
# ## Relationship between Resting Blood Pressure and Serum Cholesterol
#
# Understanding the relationship between blood pressure and cholesterol helps determine intervention strategies for managing cardiovascular risk factors.

# %%
# Visualizing the Distribution of Resting Blood Pressure
plt.figure(figsize=(10, 6))
sns.histplot(data['RestingBP'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Resting Blood Pressure')
plt.xlabel('Resting Blood Pressure')
plt.ylabel('Number of Individuals')
plt.show()

# %%
# Visualizing the Distribution of Serum Cholesterol
plt.figure(figsize=(10, 6))
sns.histplot(data['SerumCholestrol'], bins=20, kde=True, color='lightcoral')
plt.title('Distribution of Serum Cholesterol')
plt.xlabel('Serum Cholesterol')
plt.ylabel('Number of Individuals')
plt.show()

# %%
# Creating a Scatter Plot between Resting Blood Pressure and Serum Cholesterol
plt.figure(figsize=(10, 6))
sns.scatterplot(x='RestingBP', y='SerumCholestrol', data=data, color='green')
plt.title('Scatter plot between Resting Blood Pressure and Serum Cholesterol')
plt.xlabel('Resting Blood Pressure')
plt.ylabel('Serum Cholesterol')
plt.show()

# %%
# Calculating the Correlation Matrix
correlation_matrix = data[['RestingBP', 'SerumCholestrol']].corr()

# %%
# Visualizing the Correlation Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix of Blood Pressure and Cholesterol')
plt.show()

# %% [markdown]
# ## Chest Pain Type Analysis
#
# In-depth understanding of chest pain types

# %%
## Visualizing the Distribution of Chest Pain Types
plt.figure(figsize=(10, 6))
sns.countplot(x='ChestPain', data=data, palette='viridis')
plt.title('Distribution of Chest Pain Types')
plt.xlabel('Chest Pain Type')
plt.ylabel('Number of Individuals')
plt.show()

# %%
# Count the Proportion of Chest Pain Types
chest_pain_counts = data['ChestPain'].value_counts()

# List of labels corresponding to category numbers
labels = ['Typical Angina (0)', 'Atypical Angina (1)', 'Non-Anginal Pain (2)', 'Asymptomatic (3)']

# Visualizing the pie chart of chest pain type proportions with labels
plt.figure(figsize=(8, 8))
plt.pie(chest_pain_counts, labels=labels, autopct='%1.1f%%', colors=sns.color_palette('viridis'), startangle=90)
plt.title('Proportion of Chest Pain Types')
plt.show()

# %% [markdown]
# ## Resting Electrocardiogram Analysis
#
# Early indications of heart issues.

# %%
# Visualizing the Distribution of Resting Electrocardiogram Results
plt.figure(figsize=(10, 6))
sns.countplot(x='RestingrElectro', data=data, palette='viridis')
plt.title('Distribution of Resting Electrocardiogram Results')
plt.xlabel('Resting EKG Result')
plt.ylabel('Number of Individuals')
plt.show()

# %%
# Count the Proportion of Resting Electrocardiogram Results
resting_ecg_counts = data['RestingrElectro'].value_counts()

# List of labels corresponding to category numbers
labels = ['Normal (0)', 'ST-T Wave Abnormality (1)', 'Left Ventricular Hypertrophy (2)']

# Visualizing the pie chart of resting electrocardiogram result proportions
plt.figure(figsize=(8, 8))
plt.pie(resting_ecg_counts, labels=labels, autopct='%1.1f%%', colors=sns.color_palette('viridis'), startangle=90)
plt.title('Proportion of Resting Electrocardiogram Results')
plt.show()

# %% [markdown]
# ## Maximum Heart Rate Analysis
# Knowing the distribution of maximum heart rates helps in determining threshold values that may become crucial predictors in heart disease

# %%
#Distribution of maximum heart rates as potential predictors.
plt.figure(figsize=(10, 6))
sns.histplot(data=data['MaxHeartRate'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Maximum Heart Rate')
plt.xlabel('Maximum Heart Rate')
plt.ylabel('Frequency')
plt.show()

# %%
# Calculating Descriptive Statistics for Maximum Heart Rate
mean_heart_rate = data['MaxHeartRate'].mean()
median_heart_rate = data['MaxHeartRate'].median()
std_dev_heart_rate = data['MaxHeartRate'].std()

print(f"Mean Maximum Heart Rate: {mean_heart_rate}")
print(f"Median Maximum Heart Rate: {median_heart_rate}")
print(f"Standard Deviation of Maximum Heart Rate: {std_dev_heart_rate}")
# Out:
# Mean Maximum Heart Rate: 145.477
# Median Maximum Heart Rate: 146.0
# Standard Deviation of Maximum Heart Rate: 34.19026828566057

# %% [markdown]
# ### Conclusion:
# - Age Distribution Analysis:
# The age range of 40 - 50 years is identified as vulnerable to heart disease. Focusing on this age group for prevention and intervention strategies can be an effective step.
#
# - Gender Analysis:
# The majority of the dataset consists of women. It is important to consider gender differences in the development of heart health solutions.
#
# - Relationship between Resting Blood Pressure and Serum Cholesterol:
# The relationship between resting blood pressure and serum cholesterol needs attention in designing intervention strategies to manage cardiovascular risk factors. Further analysis can provide deeper insights.
#
# - Chest Pain Type Analysis:
# The most common type of chest pain is 'Typical Angina.' This indicates that typical angina symptoms can be a crucial focus in the initial assessment of patients.
#
# - Resting Electrocardiogram Analysis:
# Most resting electrocardiogram results fall into the 'Normal' category. Nevertheless, special attention should be given to cases with ST-T Wave Abnormality or Left Ventricular Hypertrophy for early diagnosis.
#
# - Maximum Heart Rate Analysis:
# The distribution of maximum heart rate has an average around 145 and a standard deviation of about 34. This can be used as a reference in determining relevant thresholds in heart disease detection models.
#
# ### Recommendations:
# - Education and Prevention:
# Focus on preventing heart disease in the age group of 40 - 50 through health education programs and early detection.
#
# - Development of Gender-Based Solutions:
# Develop heart health solutions that consider gender differences to ensure effectiveness across the entire population.
#
# - Interventions Based on Chest Pain Type:
# Identification and further handling of cases with 'Typical Angina' to support the initial assessment of patients.
#
# - Monitoring Cases with Abnormal Electrocardiograms:
# Stricter monitoring and specific management for cases with abnormal electrocardiogram results such as ST-T Wave Abnormality and Left Ventricular Hypertrophy.
#
# - Attention to Maximum Heart Rate Thresholds:
# Development of heart disease detection models can leverage the threshold of maximum heart rate as one of the important predictors.
